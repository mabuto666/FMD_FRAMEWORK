# %% [markdown]
# ![FMD_Overview](https://github.com/edkreuk/FMD_FRAMEWORK/blob/main/Images/FMD_Overview.png?raw=true)

# %%
# %pip install ms-fabric-cli pillow cairosvg --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Configuration and Parameters
#
# **Fabric Administrator Role is required to create domain**

# %%
assign_icons = True                                # Set to True to assign default icons to workspaces; set to False if you have already assigned custom icons
load_demo_data= True                                # Set to True if you want to load the demo data, otherwise set to False
lakehouse_schema_enabled = True                     # Set to True if you want to use the lakehouse schema, otherwise set to False

driver = '{ODBC Driver 18 for SQL Server}'          # Change this if you use a different driver
overwrite_variable_library=True                    # By default the Library is overwritten, change this to "False" if you have custom changes

# %% [markdown]
# ## Capacity configuration

# %%
reassign_capacity= True                                         # If set to False existing assigned capacities to workspaces will no be overwritten

capacity_name_dvlm = "Trial-Erwin"                              # Which capacity will be used for these workspaces in development
capacity_name_prod = 'Trial-Erwin'                              # Which capacity will be used for these workspaces in production
capacity_name_config = 'Trial-Erwin'                      # Which capacity will be used for this workspace for the Metadata Database
capacity_name_business_domain_dvlm = 'Trial-Erwin'              # Which capacity will be used for the workspaces in this business domain
capacity_name_business_domain_prod = 'Trial-Erwin'              # Which capacity will be used for the workspaces in this business domain

# %% [markdown]
# ## Domain and Framework settings

# %%
framework_post_fix= ''                              # post fix to be added at the end of workspace for example INTEGRATION CODE(D) FMD
if framework_post_fix != '':
   framework_post_fix= ' '+ framework_post_fix      #If empty leave as is else add a space before for better visibility

##Domains
create_domains=  True                               # If you do not have a Fabric Admin role, you need to set this option to False. For domain creation the Fabric Admin role is needed
create_business_domains = True
domain_name='INTEGRATION'                           # Main Domain for Integration for example INTEGRATION CODE(D) 
business_domain_names= ['FINANCE','SALES']          # Define business domains
domain_contributor_role = {"type": "Contributors","principals": [{"id": "86897900-8de5-4894-ae41-1b4d1642acda","type": "Group"}  ]}  # Which group(Object ID) can add or remove workspaces to this domain

##Connections
connection_fabric_datapipelines_name='CON_FMD_FABRIC_PIPELINES'
connection_fabric_notebooks_name='CON_FMD_FABRIC_NOTEBOOKS'
connection_fabric_database_name='CON_FMD_FABRIC_SQL'
connection_role =  {"role": "owner","principals": [{"id": "86897900-8de5-4894-ae41-1b4d1642acda","type": "Group"}  ]}  # Which group(Object ID) can add or remove workspaces to this domain

# %% [markdown]
# # Configuration

# %% [markdown]
# ## Repo Configuration

# %%
#FMD Framework code
##### DO NOT CHANGE UNLESS SPECIFIED OTHERWISE ####
repo_owner = "edkreuk"              # Owner of the repository
repo_name = "FMD_FRAMEWORK"         # Name of the repository
branch = "main"                     #"main" is default                    
folder_prefix = ""
###################################################

# %% [markdown]
# ## Workspace Roles Configuration

# %%
workspace_roles_code = [ # Keep emtpy [] if you only want to assign this to your personal account
                                        {
                       "principal": {
                            "id": '86897900-8de5-4894-ae41-1b4d1642acda',
                            "type": "Group"
                        },
                        "role": "admin"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        },
                        {
                       "principal": {
                            "id": 'b0bf9847-5b7a-4560-947b-b149f71d303b',
                            "type": "ServicePrincipal"
                        },
                        "role": "contributor"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        }
                    ]
workspace_roles_data =  [ # Keep emtpy [] if you only want to assign this to your personal account
                                        {
                       "principal": {
                            "id": '86897900-8de5-4894-ae41-1b4d1642acda',
                            "type": "Group"
                        },
                        "role": "admin"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        },    
                         {
                       "principal": {
                            "id": '5c906b5c-d1d7-4984-b047-adacd8d795fe',
                            "type": "Group"
                        },
                        "role": "contributor"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        },
                        {
                       "principal": {
                            "id": 'b0bf9847-5b7a-4560-947b-b149f71d303b',
                            "type": "ServicePrincipal"
                        },
                        "role": "contributor"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        }
                    ]
workspace_roles_data_business_domain = [ # Keep emtpy [] if you only want to assign this to your personal account
                    {
                      "principal": {
                            "id": '86897900-8de5-4894-ae41-1b4d1642acda',
                             "type": "Group"
                        },
                        "role": "admin"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        }
                    ]

workspace_roles_code_business_domain = [ # Keep emtpy [] if you only want to assign this to your personal account
                    {
                      "principal": {
                            "id": '86897900-8de5-4894-ae41-1b4d1642acda',
                             "type": "Group"
                        },
                        "role": "admin"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        }
                    ]

workspace_roles_reporting_business_domain = [ # Keep emtpy [] if you only want to assign this to your personal account
                    {
                        "principal": {
                            "id": '86897900-8de5-4894-ae41-1b4d1642acda',
                            "type": "Group"
                        },
                        "role": "admin"  #(choose from 'admin', 'member', 'contributor', 'viewer')
                        }
                    ]

# %% [markdown]
# ## Workspace configuration

# %%
##### DO NOT CHANGE UNLESS SPECIFIED OTHERWISE, FE ADDING NEW ENVIRONMENTS ####
environments = [
                    {
                        'environment_name' : 'development',                                     # Name of target environment
                        'workspaces': {
                            'data' : {
                                'name' : domain_name + ' DATA (D)' +  framework_post_fix,       # Name of target code workspace for development
                                'roles' : workspace_roles_data,                                 # Roles to assign to the workspace
                                'capacity_name' : capacity_name_dvlm                            # Name of target data workspace for development
                            },
                            'code' : {
                                'name' : domain_name + ' CODE (D)' +  framework_post_fix,       # Name of target data workspace for development
                                'roles' : workspace_roles_code,                                 # Roles to assign to the workspace
                                'capacity_name' : capacity_name_dvlm                            # Name of target code workspace for development
                            }
                        }
                    },
                    {
                        'environment_name' : 'production',                                      # Name of target environment
                        'workspaces': {
                            'data' : {
                                'name' : domain_name + ' DATA (P)' +  framework_post_fix,       # Name of target data workspace for production
                                'roles' : workspace_roles_data,                                 # Roles to assign to the workspace
                                'capacity_name' : capacity_name_prod                            # Name of target data workspace for production   
                            },
                            'code' : {
                                'name' : domain_name + ' CODE (P)' +  framework_post_fix,       # Name of target code workspace for production
                                'roles' : workspace_roles_code,                                 # Roles to assign to the workspace
                                'capacity_name' : capacity_name_prod                            # Name of target code workspace for production
                            }                           
                        }
                    }
                ]
###################################################

# %% [markdown]
# ## Business Domain Configuration

# %%
##### DO NOT CHANGE UNLESS SPECIFIED OTHERWISE, FE ADDING NEW ENVIRONMENTS ####
business_domain_deployment = [
                    {
                        'environment_name' : 'development',                                 # Name of target environment
                        'environment_short' : 'D',                                          # Short of target environment
                        'workspaces': {
                         
                            'data' : {
                                'roles' : workspace_roles_data_business_domain,             # Roles to assign to the workspace
                                'capacity_name' : capacity_name_business_domain_dvlm        # Name of target data workspace for development
                            },
                            'code' : {
                                'roles' : workspace_roles_code_business_domain,             # Roles to assign to the workspace
                                'capacity_name' : capacity_name_business_domain_dvlm        # Name of target code workspace for development
                            },
                            'reporting' : {
                            'roles' : workspace_roles_reporting_business_domain,            # Roles to assign to the workspace
                            'capacity_name' : capacity_name_business_domain_dvlm            # Name of target code workspace for development
                            }
                        }
                    },
                    {
                        'environment_name' : 'production',                                  # Name of target environment
                        'environment_short' : 'P',                                          # Short of target environment
                        'workspaces': {
                         
                            'data' : {
                                'roles' : workspace_roles_data_business_domain,             # Roles to assign to the workspace
                                'capacity_name' : capacity_name_business_domain_prod        # Name of target data workspace for development
                            },
                            'code' : {
                                'roles' : workspace_roles_code_business_domain,             # Roles to assign to the workspace
                                'capacity_name' : capacity_name_business_domain_prod        # Name of target code workspace for development
                            },
                            'reporting' : {
                                'roles' : workspace_roles_reporting_business_domain,        # Roles to assign to the workspace
                                'capacity_name' : capacity_name_business_domain_prod        # Name of target code workspace for development
                            }
                        }
                    }
                ]
###################################################

# %% [markdown]
# ## Fabric Database Configuration

# %%
configuration = {
                    'workspace': {
                        'name' : domain_name + ' CONFIG' +  framework_post_fix,             # Name of target workspace
                        'roles' : workspace_roles_data,                                     # Roles to assign to the workspace
                        'capacity_name' : capacity_name_config                              # Name of target capacity for the configuration workspace
                    },
                       'DatabaseName' : 'SQL_'+domain_name+'_FRAMEWORK'                     # Name of target configuration SQL Database
}

# %% [markdown]
# ## Icon Configuration

# %%
# Workspace icon definition. Setting the icons to None will delete the existing icon of the workspaces specified.
workspace_icon_def = {
    "icons": {
        "code": "fmd_code_icon.png",
        "data": "fmd_data_icon.png",
        "config": "fmd_config_icon.png",
        "reporting": "fmd_reporting_icon.png",
        "business_domain": "fmd_gold_icon.png"
    }
}

# %% [markdown]
# ## Download source & config files

# %%
import subprocess
import os
from time import sleep, time
import json
import nbformat
import shutil
import re
import requests
import zipfile
import yaml
import struct
import pyodbc
import notebookutils
import sempy.fabric as fabric
import cairosvg
import base64
import xml.etree.ElementTree as ET

from PIL import Image, ImageDraw, ImageFont
from requests.adapters import HTTPAdapter, Retry
from io import BytesIO
from zipfile import ZipFile

# %%
def download_folders_as_zip(repo_owner, repo_name, output_zip, branch="main", folders_to_extract=None, remove_folder_prefix=""):
    if folders_to_extract is None:
        folders_to_extract = []

    # Construct the URL for the GitHub API to download the repository as a zip file
    url = f"https://api.github.com/repos/{repo_owner}/{repo_name}/zipball/{branch}"
    response = requests.get(url)
    response.raise_for_status()

    # Ensure the directory for the output zip file exists
    os.makedirs(os.path.dirname(output_zip), exist_ok=True)

    # Create a zip file in memory from GitHub response
    with zipfile.ZipFile(BytesIO(response.content)) as zipf:
        # Open output zip in append mode
        with zipfile.ZipFile(output_zip, 'w') as output_zipf:
            
            for file_info in zipf.infolist():
                for folder in folders_to_extract:
                    folder_path = f"/{folder}" if not folder.startswith("/") else folder
                    if re.sub(r'^.*?/', '/', file_info.filename).startswith(folder_path):
                        file_data = zipf.read(file_info.filename)
                        parts = file_info.filename.split('/')
                        if remove_folder_prefix:
                            parts = [p for p in parts if p != remove_folder_prefix]
                        output_zipf.writestr('/'.join(parts[1:]), file_data)

def uncompress_zip_to_folder(zip_path, extract_to):
    os.makedirs(extract_to, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    os.remove(zip_path)

def copy_to_tmp(name):
    shutil.rmtree("./builtin/tmp", ignore_errors=True)
    path2zip = "./builtin/src/src.zip"

    prefixes = [
        f"src/{name}"
    ]

    with ZipFile(path2zip) as archive:
        for prefix in prefixes:
            matched_files = [file for file in archive.namelist() if file.startswith(prefix)]
            if matched_files:
                for file in matched_files:
                    archive.extract(file, "./builtin/tmp")
                return f"./builtin/tmp/{prefix}"  # Return only the first matching prefix

    return None  # Nothing found

# ✅ Combine all folders into one zip
download_folders_as_zip(repo_owner, repo_name, output_zip = "./builtin/src/src.zip", branch = branch, folders_to_extract= [f"{folder_prefix}/src"] , remove_folder_prefix = f"{folder_prefix}")
download_folders_as_zip(repo_owner, repo_name, output_zip = "./builtin/config/config.zip", branch = branch, folders_to_extract= [f"{folder_prefix}/config"] , remove_folder_prefix = f"{folder_prefix}")
# ✅ Uncompress everything into ./builtin
uncompress_zip_to_folder(zip_path = "./builtin/config/config.zip", extract_to= "./builtin")

mapping_table=[]
tasks=[]

# %% [markdown]
# # CLI Login

# %%
# Set environment parameters for Fabric CLI
token = notebookutils.credentials.getToken('pbi')
os.environ['FAB_TOKEN'] = token
os.environ['FAB_TOKEN_ONELAKE'] = token

# %% [markdown]
# # Deployment functions

# %% [markdown]
# ## Get existing connections

# %%
result = subprocess.run(["fab", "api", "-X", "get", "connections"], capture_output=True, text=True)
connections=json.loads(result.stdout)["text"]
connection_list = [item['id'] for item in connections['value']]

# %% [markdown]
# ## Load configuration

# %%
base_path = './builtin/'
config_path = os.path.join(base_path, 'config/item_config.tfi.yaml')

with open(config_path, 'r') as file:
        config = yaml.safe_load(file)

deploy_order_path = os.path.join(base_path, 'config/item_deployment.json')
with open(deploy_order_path, 'r') as file:
        item_deployment =json.load(file)

deploy_order_path = os.path.join(base_path, 'config/item_initial_setup.json')
with open(deploy_order_path, 'r') as file:
        item_initial_setup =json.load(file)

deploy_order_path = os.path.join(base_path, 'config/item_deployment_code_business_domain.json')
with open(deploy_order_path, 'r') as file:
        item_deployment_code_business_domain =json.load(file)

deploy_order_path = os.path.join(base_path, 'config/item_deployment_data_business_domain.json')
with open(deploy_order_path, 'r') as file:
        item_deployment_data_business_domain =json.load(file)

deploy_order_path = os.path.join(base_path, 'config/data_deployment.json')
with open(deploy_order_path, 'r') as file:
        data_deployment =json.load(file)

deploy_order_path = os.path.join(base_path, 'config/lakehouse_deployment.json')
with open(deploy_order_path, 'r') as file:
        lakehouse_deployment =json.load(file)

deploy_icons_path = os.path.join(base_path, 'config/fabric_icons.xml')

# Parse the XML file
tree = ET.parse(deploy_icons_path)
root = tree.getroot()

# Create a dictionary to store icon name and base64
fabric_icons_fmd = {}
for item in root.findall('icon'):
    name = item.find('name').text if item.find('name') is not None else "No name"
    base64_str = item.find('base64').text if item.find('base64') is not None else ""
    fabric_icons_fmd[name] = base64_str

# %% [markdown]
# # Deployment

# %% [markdown]
# ## Load latest version NB_UTILITIES_SETUP_FMD

# %%
def run_fab_command(command, capture_output=False, silently_continue=False, raw_output=False):
    """
    Executes a Fabric CLI command with optional output capture and error handling.
    """
    result = subprocess.run(["fab", "-c", command], capture_output=capture_output, text=True)
    if not silently_continue and (result.returncode > 0 or result.stderr):
        raise Exception(f"Error running fab command. exit_code: '{result.returncode}'; stderr: '{result}'")
    if capture_output:
        return result if raw_output else result.stdout.strip()
    return None

# %%
workspace_id = fabric.get_workspace_id()
result=run_fab_command("api -X get workspaces/"+workspace_id, capture_output=True, silently_continue=False)
workspace_name=json.loads(result)["text"]["displayName"]

for it in item_initial_setup:
    name = it["name"]
    type = it["type"]
    tmp_path = copy_to_tmp(name)

    cli_parameter = ''

    if "Notebook" in name:
        cli_parameter += " --format .py"
        result = run_fab_command(f"import {workspace_name}.Workspace/{name} -i {tmp_path} -f {cli_parameter}",capture_output=True, silently_continue=True)

# %%
# Load all notebook functions
nb_str = notebookutils.notebook.getDefinition("NB_UTILITIES_SETUP_FMD")
nb = nbformat.from_dict(json.loads(nb_str))
shell = get_ipython()
for cell in nb.cells:
    if cell.cell_type == 'code':
        code = ''.join(cell['source'])
        shell.run_cell(code)

# %% [markdown]
# ## Integration Domain

# %%
if create_domains:
    create_fabric_domain(domain_name)

# %% [markdown]
# ### Create Connections

# %%
#Create connection and get connection id

##CON_FMD_FABRIC_PIPELINES
connection_id=create_or_get_fmd_connection(connection_fabric_datapipelines_name,connection_role, 'FabricDataPipelines')
mapping_table.append({"Description": connection_fabric_datapipelines_name,"ItemType": "connection" ,"environment": 'config' ,"old_id": config["connections"]["CON_FMD_FABRIC_PIPELINES"], "new_id": connection_id})

##CON_FMD_FABRIC_NOTEBOOKS
connection_id=create_or_get_fmd_connection(connection_fabric_notebooks_name,connection_role,'Notebook' )
mapping_table.append({"Description": connection_fabric_notebooks_name,"ItemType": "connection" ,"environment": 'config' ,"old_id": config["connections"]["CON_FMD_FABRIC_NOTEBOOKS"], "new_id": connection_id})

##CON_FMD_FABRIC_SQL
connection_id=create_or_get_fmd_connection(connection_fabric_database_name,connection_role,'FabricSql' )
mapping_table.append({"Description": connection_fabric_database_name,"ItemType": "connection" ,"environment": 'config' ,"old_id": config["connections"]["CON_FMD_FABRIC_SQL"], "new_id": connection_id})

#CON_FMD_ADF_PIPELINES GET Connection id of ADF Connection if exist, when using different name, change below
connection_id = next(    (item['id'] for item in connections.get('value', [])     if item.get('displayName') == 'CON_FMD_ADF_PIPELINES'),    None )  # default if not found 
mapping_table.append({"Description": "CON_FMD_ADF_PIPELINES","ItemType": "connection" ,"environment": 'config' ,"old_id": config["connections"]["CON_FMD_ADF_PIPELINES"], "new_id": connection_id})
# Out:
# ✅ Role applied to CON_FMD_FABRIC_PIPELINES
# ✅ Role applied to CON_FMD_FABRIC_NOTEBOOKS
# ✅ Role applied to CON_FMD_FABRIC_SQL

# %% [markdown]
# ### Create workspaces(Code and Data)

# %%
for environment in environments:
    print(f"--------------------------")
    print(f"Creating/Updating Workspace: {environment['environment_name']}")
    deploy_workspaces(domain_name,workspace=environment['workspaces']['code'], workspace_name=environment['workspaces']['code']['name'], environment_name=environment['environment_name'], old_id=config["workspaces"]["workspace_code"], mapping_table=mapping_table, tasks=tasks)
    deploy_workspaces(domain_name,workspace=environment['workspaces']['data'], workspace_name=environment['workspaces']['data']['name'], environment_name=environment['environment_name'], old_id=config["workspaces"]["workspace_data"], mapping_table=mapping_table, tasks=tasks)
# Out:
# --------------------------
# Creating/Updating Workspace: development
#
# #############################################
#  - Processing: workspace INTEGRATION1 CODE (D)
#  - Workspace 'INTEGRATION1 CODE (D)' found. Workspace ID: 4f9f965d-97c9-432f-8d2c-9dd6b1885cb4
#  - Assigning capacity: Trial-Erwin
# ✅ Capacity assigned: Trial-Erwin
# --------------------------
# Updating Mapping Table: development
# * Workspace updated
# ✅ Description applied to 'INTEGRATION1 CODE (D)'
#  - Assigning Workspace roles
# ✅'{'id': '86897900-8de5-4894-ae41-1b4d1642acda', 'type': 'Group'}' assigned to admin role in 'INTEGRATION1 CODE (D)'
# ✅'{'id': 'b0bf9847-5b7a-4560-947b-b149f71d303b', 'type': 'ServicePrincipal'}' assigned to contributor role in 'INTEGRATION1 CODE (D)'
# ✅ Managed identity created in 'INTEGRATION1 CODE (D)'
# ✅ Managed identity assigned to contributor role in 'INTEGRATION1 CODE (D)'
#
# #############################################
#  - Processing: workspace INTEGRATION1 DATA (D)
#  - Workspace 'INTEGRATION1 DATA (D)' found. Workspace ID: 73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6
#  - Assigning capacity: Trial-Erwin
# ✅ Capacity assigned: Trial-Erwin
# --------------------------
# Updating Mapping Table: development
# * Workspace updated
# ✅ Description applied to 'INTEGRATION1 DATA (D)'
#  - Assigning Workspace roles
# ✅'{'id': '86897900-8de5-4894-ae41-1b4d1642acda', 'type': 'Group'}' assigned to admin role in 'INTEGRATION1 DATA (D)'
# ✅'{'id': '5c906b5c-d1d7-4984-b047-adacd8d795fe', 'type': 'Group'}' assigned to contributor role in 'INTEGRATION1 DATA (D)'
# ✅'{'id': 'b0bf9847-5b7a-4560-947b-b149f71d303b', 'type': 'ServicePrincipal'}' assigned to contributor role in 'INTEGRATION1 DATA (D)'
# ✅ Managed identity created in 'INTEGRATION1 DATA (D)'
# --------------------------
# Creating/Updating Workspace: production
#
# #############################################
#  - Processing: workspace INTEGRATION1 CODE (P)
#  - Workspace 'INTEGRATION1 CODE (P)' found. Workspace ID: f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1
#  - Assigning capacity: Trial-Erwin
# ✅ Capacity assigned: Trial-Erwin
# --------------------------
# Updating Mapping Table: production
# * Workspace updated
# ✅ Description applied to 'INTEGRATION1 CODE (P)'
#  - Assigning Workspace roles
# ✅'{'id': '86897900-8de5-4894-ae41-1b4d1642acda', 'type': 'Group'}' assigned to admin role in 'INTEGRATION1 CODE (P)'
# ✅'{'id': 'b0bf9847-5b7a-4560-947b-b149f71d303b', 'type': 'ServicePrincipal'}' assigned to contributor role in 'INTEGRATION1 CODE (P)'
# ✅ Managed identity created in 'INTEGRATION1 CODE (P)'
# ✅ Managed identity assigned to contributor role in 'INTEGRATION1 CODE (P)'
#
# #############################################
#  - Processing: workspace INTEGRATION1 DATA (P)
#  - Workspace 'INTEGRATION1 DATA (P)' found. Workspace ID: c87da4cf-2406-463c-9a64-bb458fc9e05f
#  - Assigning capacity: Trial-Erwin
# ✅ Capacity assigned: Trial-Erwin
# --------------------------
# Updating Mapping Table: production
# * Workspace updated
# ✅ Description applied to 'INTEGRATION1 DATA (P)'
#  - Assigning Workspace roles
# ✅'{'id': '86897900-8de5-4894-ae41-1b4d1642acda', 'type': 'Group'}' assigned to admin role in 'INTEGRATION1 DATA (P)'
# ✅'{'id': '5c906b5c-d1d7-4984-b047-adacd8d795fe', 'type': 'Group'}' assigned to contributor role in 'INTEGRATION1 DATA (P)'
# ✅'{'id': 'b0bf9847-5b7a-4560-947b-b149f71d303b', 'type': 'ServicePrincipal'}' assigned to contributor role in 'INTEGRATION1 DATA (P)'
# ✅ Managed identity created in 'INTEGRATION1 DATA (P)'

# %% [markdown]
# ### Create workspace(Configuration)

# %%
print(f"Creating/Updating Workspace: Configuration")
deploy_workspaces(domain_name,workspace=configuration['workspace'], workspace_name=configuration['workspace']['name'], environment_name='config', old_id=config["workspaces"]["workspace_config"], mapping_table=mapping_table, tasks=tasks)
# Out:
# Creating/Updating Workspace: Configuration
#
# #############################################
#  - Processing: workspace INTEGRATION1 CONFIG
#  - Workspace 'INTEGRATION1 CONFIG' found. Workspace ID: 195a01c4-516e-4f96-bd86-9bd2133b9741
#  - Assigning capacity: fabricedkcapacity
# ✅ Capacity assigned: fabricedkcapacity
# --------------------------
# Updating Mapping Table: config
# * Workspace updated
# ✅ Description applied to 'INTEGRATION1 CONFIG'
#  - Assigning Workspace roles
# ✅'{'id': '86897900-8de5-4894-ae41-1b4d1642acda', 'type': 'Group'}' assigned to admin role in 'INTEGRATION1 CONFIG'
# ✅'{'id': '5c906b5c-d1d7-4984-b047-adacd8d795fe', 'type': 'Group'}' assigned to contributor role in 'INTEGRATION1 CONFIG'
# ✅'{'id': 'b0bf9847-5b7a-4560-947b-b149f71d303b', 'type': 'ServicePrincipal'}' assigned to contributor role in 'INTEGRATION1 CONFIG'
# ✅ Managed identity created in 'INTEGRATION1 CONFIG'

# %% [markdown]
# ### Create Lakehouses

# %%
for environment in environments:
    print(f"\n--------------------------")
    print(f"Processing: {environment['environment_name']}")
    for workspace in [environment['workspaces']['data']]:
        exclude = []
        for it in lakehouse_deployment:

            new_id = None
            name = it["name"]
            type = it["type"]

            if name in exclude:
                continue
            deploy_item(workspace['name'],name,mapping_table, environment['environment_name'],connection_list, tasks, lakehouse_schema_enabled, it)
# Out:
# --------------------------
# Processing: development
#
# #############################################
# Deploying in INTEGRATION1 DATA (D): LH_DATA_LANDINGZONE.Lakehouse
# ✅ Folder Lakehouses assigned to item in 'INTEGRATION1 DATA (D)'
# Lakehouse already exists, skip creation
#
# #############################################
# Deploying in INTEGRATION1 DATA (D): LH_BRONZE_LAYER.Lakehouse
# ✅ Folder Lakehouses assigned to item in 'INTEGRATION1 DATA (D)'
# Lakehouse already exists, skip creation
#
# #############################################
# Deploying in INTEGRATION1 DATA (D): LH_SILVER_LAYER.Lakehouse
# ✅ Folder Lakehouses assigned to item in 'INTEGRATION1 DATA (D)'
# Lakehouse already exists, skip creation
#
# --------------------------
# Processing: production
#
# #############################################
# Deploying in INTEGRATION1 DATA (P): LH_DATA_LANDINGZONE.Lakehouse
# ✅ Folder Lakehouses assigned to item in 'INTEGRATION1 DATA (P)'
# Lakehouse already exists, skip creation
#
# #############################################
# Deploying in INTEGRATION1 DATA (P): LH_BRONZE_LAYER.Lakehouse
# ✅ Folder Lakehouses assigned to item in 'INTEGRATION1 DATA (P)'
# Lakehouse already exists, skip creation
#
# #############################################
# Deploying in INTEGRATION1 DATA (P): LH_SILVER_LAYER.Lakehouse
# ✅ Folder Lakehouses assigned to item in 'INTEGRATION1 DATA (P)'
# Lakehouse already exists, skip creation

# %% [markdown]
# ### Create Fabric database (Configuration)

# %%
for deployment_item in data_deployment:
        if deployment_item['type'] in ('SQLDatabase'):
                name = configuration['DatabaseName']
                type = deployment_item["type"]
                name=name+'.'+type
                
                deploy_item(workspace_name=configuration['workspace']['name'],name=name,mapping_table=mapping_table, environment_name='config',connection_list= connection_list,tasks= tasks, lakehouse_schema_enabled=lakehouse_schema_enabled,it=deployment_item)

                server=get_item_id(configuration['workspace']['name'], name, 'properties.serverFqdn')
                database=get_item_id(configuration['workspace']['name'], name, 'properties.databaseName')
                #Add Endpoint and databasename into mapping table so pipeline connection can be replaced
                upsert_mapping(mapping_table, {"Description":deployment_item['name'] , "environment": 'config',"ItemType": 'SQLDatabase', "old_id": deployment_item["endpoint"], "new_id": server}, keys=("Description","environment", "ItemType","old_id"))
                upsert_mapping(mapping_table, {"Description":deployment_item['name'] , "environment": 'config',"ItemType": 'SQLDatabase', "old_id": deployment_item["database"], "new_id": database}, keys=("Description","environment", "ItemType","old_id"))


##!NOTE: in Case of an error check if you're not using a trial capacitiy or the capacity you assigned is paused
# Out:
# #############################################
# Deploying in INTEGRATION1 CONFIG: SQL_INTEGRATION1_FRAMEWORK.SQLDatabase
# Creating or updating SQLDatabase: SQL_INTEGRATION1_FRAMEWORK.SQLDatabase
# * Item updated
# ✅ Description applied to SQL_INTEGRATION1_FRAMEWORK.SQLDatabase in 'INTEGRATION1 CONFIG'
# ✅ SQL_INTEGRATION1_FRAMEWORK.SQLDatabase Created/Imported'
# * 'SQL_INTEGRATION1_FRAMEWORK.SQLDatabase' imported
# ! Modifying properties may lead to unintended consequences

# %% [markdown]
# ### Create Items

# %%
#Make sure out token is still valid before we continou, sometime it can take a bit longer that's we will check it again
token = notebookutils.credentials.getToken('pbi')
os.environ['FAB_TOKEN'] = token
os.environ['FAB_TOKEN_ONELAKE'] = token

# %% [markdown]
# #### Environments

# %%
#Importing Environments when there are changes can take it bit longer because the environment need to be published
for environment in environments:
    print(f"\n--------------------------")
    print(f"Processing: {environment['environment_name']}")
    for workspace in [environment['workspaces']['code']]:
        for it in item_deployment:
            if it['type'] in ('Environment' ):
                new_id = None
                name = it["name"]
                type = it["type"]
                deploy_item(workspace['name'],name,mapping_table,environment['environment_name'],connection_list, tasks, lakehouse_schema_enabled,it)
# Out:
# --------------------------
# Processing: development
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): ENV_FMD.Environment
# Creating or updating Environment: ENV_FMD.Environment
# ✅ ENV_FMD.Environment Created/Imported'
# ✅ Folder Environments assigned to item in 'INTEGRATION1 CODE (D)'
# * 'ENV_FMD.Environment' imported
#
# --------------------------
# Processing: production
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): ENV_FMD.Environment
# Creating or updating Environment: ENV_FMD.Environment
# ✅ ENV_FMD.Environment Created/Imported'
# ✅ Folder Environments assigned to item in 'INTEGRATION1 CODE (P)'
# * 'ENV_FMD.Environment' imported

# %% [markdown]
# #### Notebooks and VariableLibrary

# %%
for environment in environments:
    print(f"\n--------------------------")
    print(f"Processing: {environment['environment_name']}")
    for workspace in [environment['workspaces']['code']]:
        for it in item_deployment:
            if it['type'] in ('Notebook','VariableLibrary' ):
                new_id = None
                name = it["name"]
                type = it["type"]
                deploy_item(workspace['name'],name,mapping_table,environment['environment_name'],connection_list, tasks, lakehouse_schema_enabled,it)
# Out:
# --------------------------
# Processing: development
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): NB_FMD_PROCESSING_PARALLEL_MAIN.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (D)'
# * 'NB_FMD_PROCESSING_PARALLEL_MAIN.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): NB_FMD_LOAD_BRONZE_SILVER.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (D)'
# * 'NB_FMD_LOAD_BRONZE_SILVER.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): NB_FMD_LOAD_LANDING_BRONZE.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (D)'
# * 'NB_FMD_LOAD_LANDING_BRONZE.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): NB_FMD_CUSTOM_NOTEBOOK_TEMPLATE.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (D)'
# * 'NB_FMD_CUSTOM_NOTEBOOK_TEMPLATE.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): NB_FMD_PROCESSING_LANDINGZONE_MAIN.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (D)'
# * 'NB_FMD_PROCESSING_LANDINGZONE_MAIN.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): NB_FMD_UTILITY_FUNCTIONS.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (D)'
# * 'NB_FMD_UTILITY_FUNCTIONS.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): VAR_FMD.VariableLibrary
# Creating or updating VariableLibrary: VAR_FMD.VariableLibrary
# ✅ VAR_FMD.VariableLibrary Created/Imported'
# ✅ Folder VariableLibraries assigned to item in 'INTEGRATION1 CODE (D)'
# * 'VAR_FMD.VariableLibrary' imported
#
# --------------------------
# Processing: production
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): NB_FMD_PROCESSING_PARALLEL_MAIN.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (P)'
# * 'NB_FMD_PROCESSING_PARALLEL_MAIN.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): NB_FMD_LOAD_BRONZE_SILVER.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (P)'
# * 'NB_FMD_LOAD_BRONZE_SILVER.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): NB_FMD_LOAD_LANDING_BRONZE.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (P)'
# * 'NB_FMD_LOAD_LANDING_BRONZE.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): NB_FMD_CUSTOM_NOTEBOOK_TEMPLATE.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (P)'
# * 'NB_FMD_CUSTOM_NOTEBOOK_TEMPLATE.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): NB_FMD_PROCESSING_LANDINGZONE_MAIN.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (P)'
# * 'NB_FMD_PROCESSING_LANDINGZONE_MAIN.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): NB_FMD_UTILITY_FUNCTIONS.Notebook
# ✅ Folder Notebooks assigned to item in 'INTEGRATION1 CODE (P)'
# * 'NB_FMD_UTILITY_FUNCTIONS.Notebook' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): VAR_FMD.VariableLibrary
# Creating or updating VariableLibrary: VAR_FMD.VariableLibrary
# ✅ VAR_FMD.VariableLibrary Created/Imported'
# ✅ Folder VariableLibraries assigned to item in 'INTEGRATION1 CODE (P)'
# * 'VAR_FMD.VariableLibrary' imported

# %%
#Make sure out token is still valid before we continou, sometime it can take a bit longer that's we will check it again
token = notebookutils.credentials.getToken('pbi')
os.environ['FAB_TOKEN'] = token
os.environ['FAB_TOKEN_ONELAKE'] = token

# %% [markdown]
# #### DataPipelines

# %%
for environment in environments:
    print(f"\n--------------------------")
    print(f"Processing: {environment['environment_name']}")
    for workspace in [environment['workspaces']['code']]:
        exclude = []
        for it in item_deployment:
            if it['type'] in ('DataPipeline'):
                new_id = None
                name = it["name"]
                type = it["type"]

                if name in exclude:
                    continue
                deploy_item(workspace['name'],name,mapping_table,environment['environment_name'],connection_list, tasks, lakehouse_schema_enabled,it)
# Out:
# --------------------------
# Processing: development
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_CUSTOM_NB.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_CUSTOM_NB.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_CUSTOM_NB.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_CUSTOM_NB.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ADLS_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ADLS_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ADLS_01.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_ADLS_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ADF.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ADF.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ADF.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_ADF.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ASQL_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ASQL_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ASQL_01.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_ASQL_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_FTP_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_FTP_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_FTP_01.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_FTP_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_SFTP_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_SFTP_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_SFTP_01.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_SFTP_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ORACLE_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COPY_FROM_ORACLE_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ORACLE_01.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COPY_FROM_ORACLE_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ORACLE.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ORACLE.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ORACLE.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_ORACLE.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ADLS.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ADLS.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ADLS.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_ADLS.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ASQL.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ASQL.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ASQL.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_ASQL.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_FTP.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_FTP.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_FTP.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_FTP.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_SFTP.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_SFTP.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_SFTP.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_SFTP.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ONELAKE.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ONELAKE.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_ONELAKE.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ADF.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_ADF.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ADF.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_ADF.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_NOTEBOOK.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LDZ_COMMAND_NOTEBOOK.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_NOTEBOOK.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LDZ_COMMAND_NOTEBOOK.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LOAD_BRONZE.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LOAD_BRONZE.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LOAD_BRONZE.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LOAD_BRONZE.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LOAD_SILVER.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LOAD_SILVER.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LOAD_SILVER.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LOAD_SILVER.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_TOOLING_POST_ASQL_TO_FMD.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_TOOLING_POST_ASQL_TO_FMD.DataPipeline
# * Item updated
# ✅ Description applied to PL_TOOLING_POST_ASQL_TO_FMD.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_TOOLING_POST_ASQL_TO_FMD.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LOAD_LANDINGZONE.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LOAD_LANDINGZONE.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LOAD_LANDINGZONE.DataPipeline in 'INTEGRATION1 CODE (D)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (D)'
# * 'PL_FMD_LOAD_LANDINGZONE.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (D): PL_FMD_LOAD_ALL.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (D): PL_FMD_LOAD_ALL.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01.DataPipeline in 'INTEGRATION1 CODE (P)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (P)'
# * 'PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): PL_FMD_LDZ_COPY_FROM_ORACLE_01.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (P): PL_FMD_LDZ_COPY_FROM_ORACLE_01.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COPY_FROM_ORACLE_01.DataPipeline in 'INTEGRATION1 CODE (P)'
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ADLS.DataPipeline in 'INTEGRATION1 CODE (P)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (P)'
# * 'PL_FMD_LDZ_COMMAND_ADLS.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): PL_FMD_LDZ_COMMAND_ASQL.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (P): PL_FMD_LDZ_COMMAND_ASQL.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ASQL.DataPipeline in 'INTEGRATION1 CODE (P)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (P)'
# * 'PL_FMD_LDZ_COMMAND_ASQL.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): PL_FMD_LDZ_COMMAND_FTP.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (P): PL_FMD_LDZ_COMMAND_FTP.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ONELAKE.DataPipeline in 'INTEGRATION1 CODE (P)'
# * Item updated
# ✅ Description applied to PL_FMD_LDZ_COMMAND_ADF.DataPipeline in 'INTEGRATION1 CODE (P)'
# * Item updated
# ✅ Description applied to PL_FMD_LOAD_BRONZE.DataPipeline in 'INTEGRATION1 CODE (P)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (P)'
# * 'PL_FMD_LOAD_BRONZE.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): PL_FMD_LOAD_SILVER.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (P): PL_FMD_LOAD_SILVER.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LOAD_SILVER.DataPipeline in 'INTEGRATION1 CODE (P)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (P)'
# * 'PL_FMD_LOAD_SILVER.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): PL_TOOLING_POST_ASQL_TO_FMD.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (P): PL_TOOLING_POST_ASQL_TO_FMD.DataPipeline
# * Item updated
# ✅ Description applied to PL_TOOLING_POST_ASQL_TO_FMD.DataPipeline in 'INTEGRATION1 CODE (P)'
# * Item updated
# ✅ Description applied to PL_FMD_LOAD_LANDINGZONE.DataPipeline in 'INTEGRATION1 CODE (P)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (P)'
# * 'PL_FMD_LOAD_LANDINGZONE.DataPipeline' imported
#
# #############################################
# Deploying in INTEGRATION1 CODE (P): PL_FMD_LOAD_ALL.DataPipeline
# Replacing connections guid in INTEGRATION1 CODE (P): PL_FMD_LOAD_ALL.DataPipeline
# * Item updated
# ✅ Description applied to PL_FMD_LOAD_ALL.DataPipeline in 'INTEGRATION1 CODE (P)'
# ✅ Folder DataPipelines assigned to item in 'INTEGRATION1 CODE (P)'
# * 'PL_FMD_LOAD_ALL.DataPipeline' imported
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COPY_FROM_CUSTOM_NB.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COPY_FROM_ADLS_01.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COPY_FROM_ADF.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COPY_FROM_ASQL_01.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COMMAND_ADLS.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COMMAND_SFTP.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COMMAND_ONELAKE.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COMMAND_NOTEBOOK.DataPipeline'...
# ! Modifying properties may lead to unintended consequences
# Setting new property for 'PL_FMD_LDZ_COMMAND_NOTEBOOK.DataPipeline'...

# %% [markdown]
# ## Business Domain

# %% [markdown]
# ### Create workspaces(Business Domains)

# %%
if create_business_domains:
    for business_domain_name in business_domain_names:
        if create_domains:
            create_fabric_domain(business_domain_name)

        for business_domain in business_domain_deployment:
            print(f"--------------------------")
            print(f"Updating Workspace: {business_domain['environment_name']}")
            deploy_workspaces(business_domain_name,workspace=business_domain['workspaces']['code'],workspace_name=business_domain_name + ' CODE ('+business_domain['environment_short']+')'+framework_post_fix,  environment_name=business_domain['environment_name'], old_id=config["workspaces"]["workspace_business_domain_code"], mapping_table=mapping_table, tasks=tasks)
            deploy_workspaces(business_domain_name,workspace=business_domain['workspaces']['data'],workspace_name=business_domain_name + ' DATA ('+business_domain['environment_short']+')'+framework_post_fix,  environment_name=business_domain['environment_name'], old_id=config["workspaces"]["workspace_business_domain_data"], mapping_table=mapping_table, tasks=tasks)
            deploy_workspaces(business_domain_name,workspace=business_domain['workspaces']['reporting'],workspace_name=business_domain_name + ' REPORTING ('+business_domain['environment_short']+')'+framework_post_fix, environment_name=business_domain['environment_name'], old_id=config["workspaces"]["workspace_business_domain_reporting"], mapping_table=mapping_table, tasks=tasks)

# %% [markdown]
# ### Create Lakehouses(Business Domains)

# %%
if create_business_domains:
    for workspace_business_domain in business_domain_deployment:
        for business_domain in business_domain_names:
            for workspace in [workspace_business_domain['workspaces']['data']]:
                exclude = []
                for it in item_deployment_data_business_domain:
                    new_id = None                    
                    name = it["name"]
                    type = it["type"]

                    if name in exclude:
                        continue
                        
                    deploy_item(business_domain + ' DATA ('+ workspace_business_domain['environment_short']+')'+framework_post_fix, name,mapping_table, workspace_business_domain['environment_name'],connection_list, tasks, lakehouse_schema_enabled,it)

# %% [markdown]
# ### Create Items(Business Domains)

# %%
if create_business_domains:
    for workspace_business_domain in business_domain_deployment:
        for business_domain_name in business_domain_names:
            for workspace in [workspace_business_domain['workspaces']['code']]:
                    for it in item_deployment_code_business_domain:
                        new_id = None
                        name = it["name"]
                        type = it["type"]
                        deploy_item(business_domain_name + ' CODE ('+ workspace_business_domain['environment_short']+')'+framework_post_fix, name,mapping_table, workspace_business_domain['environment_name'],connection_list, tasks, lakehouse_schema_enabled,it)

# %% [markdown]
# ## Workspace Icons

# %%
if assign_icons:  
    seen = set()
    workspaces = []
    # Get cluster URL for use in metadata endpoints
    cluster_base_url = get_cluster_url()

    for item in mapping_table:
        if item['ItemType'] == 'Workspace':
            key = (item['Description'], item['new_id'])
            if key not in seen:
                seen.add(key)
                workspaces.append({'displayName': item['Description'], 'id': item['new_id']})
    fabric_icons = fabric_icons_fmd 

    for workspace in workspaces:
        display_name = workspace['displayName'].lower()
        
        # Check if it's a "business domain" workspace
        is_business_domain = any(sub.lower() in display_name for sub in business_domain_names) and 'data' in display_name
        display_name = 'business_domain' if is_business_domain else display_name

        # Assign icon
        for icon_key, icon_value in workspace_icon_def['icons'].items():
            if icon_key in display_name:
                workspace["icon"] = icon_value
                workspace_icon = fabric_icons.get(icon_value)
                break
        else:
            workspace["icon"] = None
            workspace_icon = None

        workspace["icon_base64img"] = workspace_icon

# %%
if assign_icons:
    # Dry run - Display pre and post icons based on specified workspace filters and workspace icon definition. Will NOT update any icons!
    display_workspace_icons(workspaces)
    sleep(2)
# Out:
# <table width='100%'><th style='text-align:left'>Workspace name</th><th style='text-align:left'>Workspace ID</th><th style='text-align:left; width:100px'>Old icon</th><th style='text-align:left; width:100px'>New icon</th><tr><th style='text-align:left'>INTEGRATION1 CODE (D)</td><td style='text-align:left'>4f9f965d-97c9-432f-8d2c-9dd6b1885cb4</td><td style='text-align:left'><img height='24' src='https://wabi-west-europe-e-primary-redirect.analysis.windows.net/powerbi/resource/images/2/c183ff6a-8ca1-4185-9378-af980978377c/FolderIcon/BlobIdV2-4b9d5da1-f43f-4590-998e-781d27172d03y4KCZiNvj88jsdk.png'/></td><td style='text-align:left'><img height='24' src='data:image/png;base64,...' /></td></tr><tr><th style='text-align:left'>INTEGRATION1 DATA (D)</td><td style='text-align:left'>73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6</td><td style='text-align:left'><img height='24' src='https://wabi-west-europe-e-primary-redirect.analysis.windows.net/powerbi/resource/images/2/c183ff6a-8ca1-4185-9378-af980978377c/FolderIcon/BlobIdV2-0d533466-53c1-4db0-8757-ef1b6e91fe2e9Rm620Vda6dILclGAcgKOQUlMwNW1VHiXS.png'/></td><td style='text-align:left'><img height='24' src='data:image/png;base64,...' /></td></tr><tr><th style='text-align:left'>INTEGRATION1 CODE (P)</td><td style='text-align:left'>f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1</td><td style='text-align:left'><img height='24' src='https://wabi-west-europe-e-primary-redirect.analysis.windows.net/powerbi/resource/images/2/c183ff6a-8ca1-4185-9378-af980978377c/FolderIcon/BlobIdV2-52b2020d-5cdc-4b27-bf31-17a629cd4da9W58.gfb8yqAkBMeqa4w-dUUSa-3O7L2W.png'/></td><td style='text-align:left'><img height='24' src='data:image/png;base64,...' /></td></tr><tr><th style='text-align:left'>INTEGRATION1 DATA (P)</td><td style='text-align:left'>c87da4cf-2406-463c-9a64-bb458fc9e05f</td><td style='text-align:left'><img height='24' src='https://wabi-west-europe-e-primary-redirect.analysis.windows.net/powerbi/resource/images/2/c183ff6a-8ca1-4185-9378-af980978377c/FolderIcon/BlobIdV2-c77a0426-3f3b-446e-8585-9aeb47e210d3Unbr6NzqRfmagzwAxi5KT6sWrNMON6MW-WvqsqdTOoo=.png'/></td><td style='text-align:left'><img height='24' src='data:image/png;base64,...' /></td></tr><tr><th style='text-align:left'>INTEGRATION1 CONFIG</td><td style='text-align:left'>195a01c4-516e-4f96-bd86-9bd2133b9741</td><td style='text-align:left'><img height='24' src='https://wabi-west-europe-e-primary-redirect.analysis.windows.net/powerbi/resource/images/2/c183ff6a-8ca1-4185-9378-af980978377c/FolderIcon/BlobIdV2-6f361662-80b7-4c28-928d-aea19b25aaa51DtIaVEzEVcxgkIH7S9nNq-FqvQoxm1DcVYwgJGtLXs=.png'/></td><td style='text-align:left'><img height='24' src='data:image/png;base64,...' /></td></tr>

# %% [markdown]
# ### Deploy Workspace Icons

# %%
if assign_icons:
    for workspace in workspaces:
            set_workspace_icon(workspace.get('id'), workspace.get('icon_base64img'))

# %% [markdown]
# ## Create SQL deployment Manifest

# %% [markdown]
# ### Add Connections to Fabric Database

# %%
custom_sql_deployment = {"queries_stored_procedures": []}
for connection in connections['value']:
    
    display_name = connection.get('displayName', '')
    if display_name and display_name.startswith('CON_FMD'):
        connection_type = connection.get('connectionDetails', {}).get('type', 'Unknown')
        connection_id = connection.get('id')
      
        exec_statement = (
            f"EXEC [integration].[sp_UpsertConnection] "
            f"@ConnectionGuid = \"{connection_id}\", "
            f"@Name = \"{display_name}\", "
            f"@Type = \"{connection_type}\", "
            f"@IsActive = 1"
        )
        custom_sql_deployment["queries_stored_procedures"].append(exec_statement)
        custom_sql_deployment["queries_stored_procedures"].append(f'EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1')
        custom_sql_deployment["queries_stored_procedures"].append(f'EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1')

# %% [markdown]
# ### Add DataSources to Fabric Database

# %%
custom_sql_deployment["queries_stored_procedures"].append("""
    DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'LH_DATA_LANDINGZONE' and Type='ONELAKE_TABLES_01')
    DECLARE @ConnectionIdInternal INT = (SELECT ConnectionId FROM integration.Connection WHERE ConnectionGuid = '00000000-0000-0000-0000-000000000000')
    EXECUTE [integration].[sp_UpsertDataSource] 
        @ConnectionId = @ConnectionIdInternal
        ,@DataSourceId = @DataSourceIdInternal
        ,@Name = 'LH_DATA_LANDINGZONE'
        ,@Namespace = 'ONELAKE'
        ,@Type = 'ONELAKE_TABLES_01'
        ,@Description = 'ONELAKE_TABLES'
        ,@IsActive = 1
""")
custom_sql_deployment["queries_stored_procedures"].append("""
    DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'LH_DATA_LANDINGZONE' and Type ='ONELAKE_FILES_01')
    DECLARE @ConnectionIdInternal INT = (SELECT ConnectionId FROM integration.Connection WHERE ConnectionGuid = '00000000-0000-0000-0000-000000000000')
    EXECUTE [integration].[sp_UpsertDataSource] 
        @ConnectionId = @ConnectionIdInternal
        ,@DataSourceId = @DataSourceIdInternal
        ,@Name = 'LH_DATA_LANDINGZONE'
        ,@Namespace = 'ONELAKE'
        ,@Type = 'ONELAKE_FILES_01'
        ,@Description = 'ONELAKE_FILES'
        ,@IsActive = 1
""")
custom_sql_deployment["queries_stored_procedures"].append("""
        DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'CUSTOM_NOTEBOOK' and Type='NOTEBOOK')
        DECLARE @ConnectionIdInternal INT = (SELECT ConnectionId FROM integration.Connection WHERE ConnectionGuid = '00000000-0000-0000-0000-000000000001')
        EXECUTE [integration].[sp_UpsertDataSource] 
            @ConnectionId = @ConnectionIdInternal
            ,@DataSourceId = @DataSourceIdInternal
            ,@Name = 'CUSTOM_NOTEBOOK'
            ,@Namespace = 'NB'
            ,@Type = 'NOTEBOOK'
            ,@Description = 'Custom Notebook'
            ,@IsActive = 1
""")

# %% [markdown]
# ### Add Workspaces to Fabric Database

# %%
#add all created workspace to database
unique_items = {}
for item in mapping_table:
    if item.get("ItemType") == "Workspace":
        unique_items[item["new_id"]] = item["Description"]

# Convert to list of tuples or dicts
workspaces = [{"Description": desc, "new_id": nid} for nid, desc in unique_items.items()]

for workspace in workspaces:
    print(f'EXEC [integration].[sp_UpsertWorkspace](@WorkspaceId = "{workspace["new_id"]}" ,@Name = "{workspace["Description"]}")')
    custom_sql_deployment["queries_stored_procedures"].append(f'EXEC [integration].[sp_UpsertWorkspace] @WorkspaceId = "{workspace["new_id"]}", @Name = "{workspace["Description"]}"')
# Out:
# EXEC [integration].[sp_UpsertWorkspace](@WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "INTEGRATION1 CODE (D)")
# EXEC [integration].[sp_UpsertWorkspace](@WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "INTEGRATION1 DATA (D)")
# EXEC [integration].[sp_UpsertWorkspace](@WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "INTEGRATION1 CODE (P)")
# EXEC [integration].[sp_UpsertWorkspace](@WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "INTEGRATION1 DATA (P)")
# EXEC [integration].[sp_UpsertWorkspace](@WorkspaceId = "195a01c4-516e-4f96-bd86-9bd2133b9741" ,@Name = "INTEGRATION1 CONFIG")

# %% [markdown]
# ### Add Data Pipelines to Fabric Database

# %%
for environment in environments:
    result = run_fab_command(f"api -X get workspaces/{environment['workspaces']['code']['id']}/items", capture_output=True, silently_continue=True)
    existing_items = json.loads(result)['text']
    for item in existing_items.get('value', []):
        if item['type'] == 'DataPipeline':
            print(f'EXEC [integration].[sp_UpsertPipeline] @PipelineId = "{item["id"]}", @WorkspaceId = "{environment["workspaces"]["code"]["id"]}" ,@Name = "{item["displayName"]}"')
            custom_sql_deployment["queries_stored_procedures"].append(f'EXEC [integration].[sp_UpsertPipeline] @PipelineId = "{item["id"]}", @WorkspaceId = "{environment["workspaces"]["data"]["id"]}" ,@Name = "{item["displayName"]}"')
# Out:
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "e0dd40ac-9803-49d9-babf-aa964b129b0b", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_CUSTOM_NB"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "f3b6c9b7-64a2-4b38-b31a-727f16e7d9bb", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADLS_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "8d3c7b1d-6a94-4230-a506-4eacbe1279e1", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADF"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "7f08acf2-cc0e-42e5-8c0b-bcb05240c426", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_ASQL_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "2c1f7348-6420-4c38-ade1-9d95baa1f969", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_FTP_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "3b608f2a-2a33-454f-9462-678e94242858", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_SFTP_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d6c0ad37-aab0-40c0-9b17-c04cd4068d28", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "7f93e79c-8a8f-4137-9d8a-1b9ad90ec634", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "c231cd71-1b4f-4488-9db7-c914aebebc1f", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COPY_FROM_ORACLE_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "378fd030-0c26-4064-925a-59967702d0f8", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_ORACLE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "b4f3b8a3-9b1e-440c-b35a-6f100bf9f067", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_ADLS"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "ce8e1513-8b7f-404c-9ff6-e0d47e052d12", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_ASQL"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "e4687fd3-d48c-4b0c-9121-d5d0b055bcb1", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_FTP"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "221fb782-ce00-4ae2-972e-bc04aa548a85", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_SFTP"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "7ef84f31-b3ca-45d0-aee0-c99f44cfac1b", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_ONELAKE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "2b7c97b3-bde1-44dd-9316-bd0ad676765e", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_ADF"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "137136f6-6b8d-4a1d-bfba-dc649cbfaed3", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LDZ_COMMAND_NOTEBOOK"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "f2ec1452-bfa7-424e-8178-ee274b12e3ec", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LOAD_BRONZE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "df826c9e-e16c-4100-8a64-89270af78855", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LOAD_SILVER"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "bd788f17-1de4-43c6-a597-6742a7ac1a2e", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_TOOLING_POST_ASQL_TO_FMD"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "892ed1f1-bd62-47fc-8dfb-64c4877d4851", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LOAD_LANDINGZONE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "b255eed9-6108-490f-81f4-7acbdf60d60d", @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4" ,@Name = "PL_FMD_LOAD_ALL"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "1ee9a66a-5e41-4a19-b0ae-ce24b86fd5fd", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_CUSTOM_NB"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "828a3c65-67b2-4e47-a09f-d32ec3148b18", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADLS_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d2ebf788-1587-41ff-937e-2968ef6ef39b", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADF"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "e33261ba-d7e0-4d10-9763-286dc402a902", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_ASQL_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "732cfbb4-24bd-437d-8664-76339efb8223", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_FTP_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "9dc2f750-39ed-400a-b33c-baf0f393a45c", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_SFTP_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "8a8c1967-2c15-4aaf-a4b9-a91543b75913", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "566d7902-b680-4955-971e-d4e742c18afa", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d363a9a6-e8cc-4a73-8a6f-e82dce036518", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COPY_FROM_ORACLE_01"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "46e4043d-f606-4c80-a0c6-cb2b9d89e98b", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_ORACLE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "98f57fef-1e88-4aa1-a4bd-5599bc7d2acb", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_ADLS"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "88e2852e-85ec-4748-914f-1b6c52f34029", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_ASQL"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "6cd42cb0-295d-4cd8-b533-302ddde928e4", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_FTP"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "6a19aad6-bcb2-4710-bdfb-5de01adfcc19", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_SFTP"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "75c10303-5381-4068-b464-0833788e8b52", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_ONELAKE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "a2e8cc67-ce7a-431d-a6c7-ddbe1101e840", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_ADF"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "c1e03dea-51f0-4af0-be1c-8d1758efeca7", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LDZ_COMMAND_NOTEBOOK"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "6155664a-ef3c-45f2-a264-d8865e56b4ec", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LOAD_BRONZE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d42b6a02-804a-4990-9b88-84dce0275a71", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LOAD_SILVER"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "961e6d6b-1ecd-4ec3-9720-fd9583b0d5dd", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_TOOLING_POST_ASQL_TO_FMD"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "59c8e02f-ffaf-4822-aa86-341b5af1f629", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LOAD_LANDINGZONE"
# EXEC [integration].[sp_UpsertPipeline] @PipelineId = "525805a5-2d57-4901-a7a8-b25eb1bdda39", @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1" ,@Name = "PL_FMD_LOAD_ALL"

# %%
for workspace_business_domain in business_domain_deployment:
    for business_domain_name in business_domain_names:
        for workspace in [workspace_business_domain['workspaces']['code']]:
                workspace_id = get_workspace_id_by_name(business_domain_name + ' CODE ('+ workspace_business_domain['environment_short']+')'+framework_post_fix)
                result = run_fab_command(f"api -X get workspaces/{workspace_id}/items", capture_output=True, silently_continue=True)
                existing_items = json.loads(result)['text']
                for item in existing_items.get('value', []):
                    if item['type'] == 'DataPipeline':
                        print(f'EXEC [integration].[sp_UpsertPipeline] @PipelineId = "{item["id"]}", @WorkspaceId = "{workspace_id}" ,@Name = "{item["displayName"]}"')
                        custom_sql_deployment["queries_stored_procedures"].append(f'EXEC [integration].[sp_UpsertPipeline] @PipelineId = "{item["id"]}", @WorkspaceId = "{workspace_id}" ,@Name = "{item["displayName"]}"')

# %% [markdown]
# ### Add Lakehouses to Fabric Database

# %%
for environment in environments:
    result = run_fab_command(f"api -X get workspaces/{environment['workspaces']['data']['id']}/items", capture_output=True, silently_continue=True)
    existing_items = json.loads(result)['text']
    for item in existing_items.get('value', []):
        if item['type'] == 'Lakehouse':
            print(f'EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "{item["id"]}", @WorkspaceId = "{environment["workspaces"]["data"]["id"]}" ,@Name = "{item["displayName"]}"')
            custom_sql_deployment["queries_stored_procedures"].append(f'EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "{item["id"]}", @WorkspaceId = "{environment["workspaces"]["data"]["id"]}" ,@Name = "{item["displayName"]}"')
# Out:
# EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "cb0739cd-4bc4-48f1-905f-fef14e972850", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "LH_DATA_LANDINGZONE"
# EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "d3f349b2-ac73-44b2-aa69-9045845eb995", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "LH_BRONZE_LAYER"
# EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "3d3ae552-69ee-4f73-bb3c-4c2cb6ef81e6", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "LH_SILVER_LAYER"
# EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "40dd36f0-c233-4ce8-94d8-28987d0fda19", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "LH_DATA_LANDINGZONE"
# EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "2bf1c80f-2bf7-46dd-a3b9-2ed690585581", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "LH_BRONZE_LAYER"
# EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "fc2718b7-56a1-44a0-a1f3-58b89db799c2", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "LH_SILVER_LAYER"

# %%
if create_business_domains:
    for workspace_business_domain in business_domain_deployment:
        for business_domain_name in business_domain_names:
            for workspace in [workspace_business_domain['workspaces']['data']]:
                    workspace_id = get_workspace_id_by_name(business_domain_name + ' DATA ('+ workspace_business_domain['environment_short']+')'+framework_post_fix)
                    result = run_fab_command(f"api -X get workspaces/{workspace_id}/items", capture_output=True, silently_continue=True)
                    existing_items = json.loads(result)['text']
                    for item in existing_items.get('value', []):
                        if item['type'] == 'Lakehouse':
                            print(f'EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "{item["id"]}", @WorkspaceId = "{workspace_id}" ,@Name = "{item["displayName"]}"')
                            custom_sql_deployment["queries_stored_procedures"].append(f'EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "{item["id"]}", @WorkspaceId = "{workspace_id}" ,@Name = "{item["displayName"]}"')

# %% [markdown]
# ### Add Demo data for testing to Fabric Database

# %%
if load_demo_data:  
    demo_sql_deployment = {"queries_stored_procedures": []}
    demo_sql_deployment["queries_stored_procedures"].append("""
        DECLARE @LandingzoneEntityIdInternal INT = (SELECT LandingzoneEntityId FROM integration.LandingzoneEntity WHERE SourceSchema = 'in' and SourceName = 'customer')
        DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'LH_DATA_LANDINGZONE' and Type='ONELAKE_TABLES_01')
        DECLARE @LakehouseIdInternal INT = (SELECT top 1 LakehouseId FROM integration.Lakehouse WHERE Name = 'LH_DATA_LANDINGZONE')
        EXECUTE [integration].[sp_UpsertLandingzoneEntity] 
            @LandingzoneEntityId = @LandingzoneEntityIdInternal
            ,@DataSourceId = @DataSourceIdInternal
            ,@LakehouseId = @LakehouseIdInternal
            ,@SourceSchema = 'in'
            ,@SourceName = 'customer'
            ,@SourceCustomSelect = ''
            ,@FileName = 'customer'
            ,@FilePath = 'fmd'
            ,@FileType = 'parquet'
            ,@IsIncremental = 0
            ,@IsIncrementalColumn = ''
            ,@IsActive = 1
            ,@CustomNotebookName = ''
    """)
    demo_sql_deployment["queries_stored_procedures"].append("""
        DECLARE @LandingzoneEntityIdInternal INT = (SELECT LandingzoneEntityId FROM integration.LandingzoneEntity WHERE SourceSchema = 'in' and SourceName = 'customer')
        DECLARE @BronzeLayerEntityIdInternal INT = (SELECT BronzeLayerEntityId FROM integration.BronzeLayerEntity WHERE [Schema] = 'in' and [Name] = 'customer')
        DECLARE @LakehouseIdInternal INT = (SELECT top 1 LakehouseId FROM integration.Lakehouse WHERE Name = 'LH_BRONZE_LAYER')
        EXECUTE [integration].[sp_UpsertBronzeLayerEntity] 
            @BronzeLayerEntityId = @BronzeLayerEntityIdInternal
            ,@LandingzoneEntityId = @LandingzoneEntityIdInternal
            ,@Schema = 'in'
            ,@Name = 'customer'
            ,@FileType = 'Delta'
            ,@LakehouseId = @LakehouseIdInternal
            ,@PrimaryKeys = 'CustomerId'
            ,@IsActive = 1
    """)
    demo_sql_deployment["queries_stored_procedures"].append("""
        DECLARE @BronzeLayerEntityIdInternal INT = (SELECT BronzeLayerEntityId FROM integration.BronzeLayerEntity WHERE [Schema] = 'in' and [Name] = 'customer')
        DECLARE @SilverLayerEntityIdInternal INT = (SELECT SilverLayerEntityId FROM integration.SilverLayerEntity WHERE [Schema] = 'in' and [Name] = 'customer')
        DECLARE @LakehouseIdInternal INT = (SELECT top 1 LakehouseId FROM integration.Lakehouse WHERE Name = 'LH_SILVER_LAYER')
        EXECUTE [integration].[sp_UpsertSilverLayerEntity] 
            @SilverLayerEntityId = @SilverLayerEntityIdInternal
            ,@BronzeLayerEntityId = @BronzeLayerEntityIdInternal
            ,@LakehouseId = @LakehouseIdInternal
            ,@Name = 'customer'
            ,@Schema = 'in'
            ,@FileType = 'delta'
            ,@IsActive = 1
    """)

# %% [markdown]
# ## Deploy SQL Code

# %%
#Make sure out token is still valid before we continou, sometime it can take a bit longer that's we will check it again
token = notebookutils.credentials.getToken('pbi')
os.environ['FAB_TOKEN'] = token
os.environ['FAB_TOKEN_ONELAKE'] = token

# %%
for deployment_item in data_deployment:
        if deployment_item['type'] in ('SQLDatabase'):
                name = configuration['DatabaseName']
                type = deployment_item["type"]
                name=name+'.'+type
                if server =='':         #it was already set, just in case
                    server=get_item_id(configuration['workspace']['name'], name, 'properties.serverFqdn')
                if database =='':    
                    database=get_item_id(configuration['workspace']['name'], name, 'properties.databaseName')

try:
    i = 0

    token = notebookutils.credentials.getToken('pbi').encode('utf-16-le')
    token_struct = struct.pack(f'<I{len(token)}s', len(token), token)

    print(f"DRIVER={driver};SERVER={server};PORT=1433;DATABASE={database};")
    connection = pyodbc.connect(f"DRIVER={driver};SERVER={server};DATABASE={database};", attrs_before={1256:token_struct}, timeout=12)

    with connection.cursor() as cursor:
        cursor.execute("SELECT 1")  # Execute the warm-up query (a simple query like 'SELECT 1' can be used)
        cursor.fetchone()
        connection.timeout = 10  # Setting a lower timeout for subsequent queries

    for i, query in enumerate(custom_sql_deployment["queries_stored_procedures"]):
        print(f' - execute "{query}"')
        cursor.execute(query)
        cursor.commit()
    for i, query in enumerate(demo_sql_deployment["queries_stored_procedures"]):
        print(f' - execute "{query}"')
        cursor.execute(query)
        cursor.commit()

    tasks.append({"task_name":f"{workspace.get('displayName')} {database} query {i}", "task_duration": 1, "status": f"success"})
except pyodbc.OperationalError as e:
    print(e) 
    tasks.append({"task_name":f"{workspace.get('displayName')} {database} query {i}", "task_duration": 1, "status": f"pyodbc failed: {e}"})
except Exception as e:
    print(e) 
    tasks.append({"task_name":f"{workspace.get('displayName')} {database} query {i}", "task_duration": 1, "status": f"failed: {e}"})
# Out:
# DRIVER={ODBC Driver 18 for SQL Server};SERVER=nl7yhqnbrscude3yv6mas6bxpq-yqavuglokgle7pmgtpjbgo4xie.database.fabric.microsoft.com,1433;PORT=1433;DATABASE=SQL_INTEGRATION1_FRAMEWORK-e318f9b3-46b7-4bea-a40c-8062f8ea2801;
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "cf673e6a-13f6-4ebb-9cbb-4ba4ab390818", @Name = "CON_FMD_ASQL_01", @Type = "SQL", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "6d8146c6-a438-47df-94e2-540c552eb6d7", @Name = "CON_FMD_FABRIC_PIPELINES", @Type = "FabricDataPipelines", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "a0581b6e-5e38-46eb-bab2-7f08e9a35c30", @Name = "CON_FMD_ADLS_01", @Type = "AzureDataLakeStorage", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "11a8e5fe-fbca-4822-9ba4-9162cf56e6dd", @Name = "CON_FMD_ASQL_02", @Type = "SQL", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "372237f9-709a-48f8-8fb2-ce06940c990e", @Name = "CON_FMD_FABRIC_SQL", @Type = "FabricSql", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "da561b41-2827-4f95-a7aa-e03e3538224f", @Name = "CON_FMD_FABRIC_API", @Type = "WebForPipeline", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "02e107b8-e97e-4b00-a28c-668cf9ce3d9a", @Name = "CON_FMD_ADF_PIPELINES", @Type = "AzureDataFactory", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "c9c39c2b-e978-4503-af42-c58bad718852", @Name = "CON_FMD_FTP_01", @Type = "FTP", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "bdb611ce-70ec-4d13-9b6e-231a5d1b303a", @Name = "CON_FMD_SFTP_01", @Type = "SFTP", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "5929775e-aff1-430c-b56e-f855d0bc63b8", @Name = "CON_FMD_FABRIC_NOTEBOOKS", @Type = "Notebook", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "d8d71258-b459-4720-b76a-56a3b17be2a1", @Name = "CON_FMD_TEST", @Type = "FabricDataPipelines", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000001", @Name = "CON_FMD_NOTEBOOK", @Type = "NOTEBOOK", @IsActive = 1"
#  - execute "EXEC [integration].[sp_UpsertConnection] @ConnectionGuid = "00000000-0000-0000-0000-000000000000", @Name = "CON_FMD_ONELAKE", @Type = "ONELAKE", @IsActive = 1"
#  - execute "
#     DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'LH_DATA_LANDINGZONE' and Type='ONELAKE_TABLES_01')
#     DECLARE @ConnectionIdInternal INT = (SELECT ConnectionId FROM integration.Connection WHERE ConnectionGuid = '00000000-0000-0000-0000-000000000000')
#     EXECUTE [integration].[sp_UpsertDataSource]
#         @ConnectionId = @ConnectionIdInternal
#         ,@DataSourceId = @DataSourceIdInternal
#         ,@Name = 'LH_DATA_LANDINGZONE'
#         ,@Namespace = 'ONELAKE'
#         ,@Type = 'ONELAKE_TABLES_01'
#         ,@Description = 'ONELAKE_TABLES'
#         ,@IsActive = 1
# "
#  - execute "
#     DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'LH_DATA_LANDINGZONE' and Type ='ONELAKE_FILES_01')
#     DECLARE @ConnectionIdInternal INT = (SELECT ConnectionId FROM integration.Connection WHERE ConnectionGuid = '00000000-0000-0000-0000-000000000000')
#     EXECUTE [integration].[sp_UpsertDataSource]
#         @ConnectionId = @ConnectionIdInternal
#         ,@DataSourceId = @DataSourceIdInternal
#         ,@Name = 'LH_DATA_LANDINGZONE'
#         ,@Namespace = 'ONELAKE'
#         ,@Type = 'ONELAKE_FILES_01'
#         ,@Description = 'ONELAKE_FILES'
#         ,@IsActive = 1
# "
#  - execute "
#         DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'CUSTOM_NOTEBOOK' and Type='NOTEBOOK')
#         DECLARE @ConnectionIdInternal INT = (SELECT ConnectionId FROM integration.Connection WHERE ConnectionGuid = '00000000-0000-0000-0000-000000000001')
#         EXECUTE [integration].[sp_UpsertDataSource]
#             @ConnectionId = @ConnectionIdInternal
#             ,@DataSourceId = @DataSourceIdInternal
#             ,@Name = 'CUSTOM_NOTEBOOK'
#             ,@Namespace = 'NB'
#             ,@Type = 'NOTEBOOK'
#             ,@Description = 'Custom Notebook'
#             ,@IsActive = 1
# "
#  - execute "EXEC [integration].[sp_UpsertWorkspace] @WorkspaceId = "4f9f965d-97c9-432f-8d2c-9dd6b1885cb4", @Name = "INTEGRATION1 CODE (D)""
#  - execute "EXEC [integration].[sp_UpsertWorkspace] @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6", @Name = "INTEGRATION1 DATA (D)""
#  - execute "EXEC [integration].[sp_UpsertWorkspace] @WorkspaceId = "f42831c2-1b68-4a3a-8c1c-d6357c7e5ea1", @Name = "INTEGRATION1 CODE (P)""
#  - execute "EXEC [integration].[sp_UpsertWorkspace] @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f", @Name = "INTEGRATION1 DATA (P)""
#  - execute "EXEC [integration].[sp_UpsertWorkspace] @WorkspaceId = "195a01c4-516e-4f96-bd86-9bd2133b9741", @Name = "INTEGRATION1 CONFIG""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "e0dd40ac-9803-49d9-babf-aa964b129b0b", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_CUSTOM_NB""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "f3b6c9b7-64a2-4b38-b31a-727f16e7d9bb", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADLS_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "8d3c7b1d-6a94-4230-a506-4eacbe1279e1", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADF""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "7f08acf2-cc0e-42e5-8c0b-bcb05240c426", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_ASQL_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "2c1f7348-6420-4c38-ade1-9d95baa1f969", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_FTP_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "3b608f2a-2a33-454f-9462-678e94242858", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_SFTP_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d6c0ad37-aab0-40c0-9b17-c04cd4068d28", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "7f93e79c-8a8f-4137-9d8a-1b9ad90ec634", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "c231cd71-1b4f-4488-9db7-c914aebebc1f", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COPY_FROM_ORACLE_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "378fd030-0c26-4064-925a-59967702d0f8", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_ORACLE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "b4f3b8a3-9b1e-440c-b35a-6f100bf9f067", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_ADLS""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "ce8e1513-8b7f-404c-9ff6-e0d47e052d12", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_ASQL""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "e4687fd3-d48c-4b0c-9121-d5d0b055bcb1", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_FTP""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "221fb782-ce00-4ae2-972e-bc04aa548a85", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_SFTP""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "7ef84f31-b3ca-45d0-aee0-c99f44cfac1b", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_ONELAKE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "2b7c97b3-bde1-44dd-9316-bd0ad676765e", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_ADF""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "137136f6-6b8d-4a1d-bfba-dc649cbfaed3", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LDZ_COMMAND_NOTEBOOK""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "f2ec1452-bfa7-424e-8178-ee274b12e3ec", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LOAD_BRONZE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "df826c9e-e16c-4100-8a64-89270af78855", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LOAD_SILVER""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "bd788f17-1de4-43c6-a597-6742a7ac1a2e", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_TOOLING_POST_ASQL_TO_FMD""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "892ed1f1-bd62-47fc-8dfb-64c4877d4851", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LOAD_LANDINGZONE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "b255eed9-6108-490f-81f4-7acbdf60d60d", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "PL_FMD_LOAD_ALL""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "1ee9a66a-5e41-4a19-b0ae-ce24b86fd5fd", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_CUSTOM_NB""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "828a3c65-67b2-4e47-a09f-d32ec3148b18", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADLS_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d2ebf788-1587-41ff-937e-2968ef6ef39b", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_ADF""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "e33261ba-d7e0-4d10-9763-286dc402a902", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_ASQL_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "732cfbb4-24bd-437d-8664-76339efb8223", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_FTP_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "9dc2f750-39ed-400a-b33c-baf0f393a45c", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_SFTP_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "8a8c1967-2c15-4aaf-a4b9-a91543b75913", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_FILES_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "566d7902-b680-4955-971e-d4e742c18afa", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_ONELAKE_TABLES_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d363a9a6-e8cc-4a73-8a6f-e82dce036518", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COPY_FROM_ORACLE_01""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "46e4043d-f606-4c80-a0c6-cb2b9d89e98b", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_ORACLE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "98f57fef-1e88-4aa1-a4bd-5599bc7d2acb", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_ADLS""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "88e2852e-85ec-4748-914f-1b6c52f34029", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_ASQL""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "6cd42cb0-295d-4cd8-b533-302ddde928e4", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_FTP""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "6a19aad6-bcb2-4710-bdfb-5de01adfcc19", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_SFTP""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "75c10303-5381-4068-b464-0833788e8b52", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_ONELAKE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "a2e8cc67-ce7a-431d-a6c7-ddbe1101e840", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_ADF""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "c1e03dea-51f0-4af0-be1c-8d1758efeca7", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LDZ_COMMAND_NOTEBOOK""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "6155664a-ef3c-45f2-a264-d8865e56b4ec", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LOAD_BRONZE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "d42b6a02-804a-4990-9b88-84dce0275a71", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LOAD_SILVER""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "961e6d6b-1ecd-4ec3-9720-fd9583b0d5dd", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_TOOLING_POST_ASQL_TO_FMD""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "59c8e02f-ffaf-4822-aa86-341b5af1f629", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LOAD_LANDINGZONE""
#  - execute "EXEC [integration].[sp_UpsertPipeline] @PipelineId = "525805a5-2d57-4901-a7a8-b25eb1bdda39", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "PL_FMD_LOAD_ALL""
#  - execute "EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "cb0739cd-4bc4-48f1-905f-fef14e972850", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "LH_DATA_LANDINGZONE""
#  - execute "EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "d3f349b2-ac73-44b2-aa69-9045845eb995", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "LH_BRONZE_LAYER""
#  - execute "EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "3d3ae552-69ee-4f73-bb3c-4c2cb6ef81e6", @WorkspaceId = "73ca6a8e-95b9-42f3-af2c-b0d72eae4ef6" ,@Name = "LH_SILVER_LAYER""
#  - execute "EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "40dd36f0-c233-4ce8-94d8-28987d0fda19", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "LH_DATA_LANDINGZONE""
#  - execute "EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "2bf1c80f-2bf7-46dd-a3b9-2ed690585581", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "LH_BRONZE_LAYER""
#  - execute "EXEC [integration].[sp_UpsertLakehouse] @LakehouseId = "fc2718b7-56a1-44a0-a1f3-58b89db799c2", @WorkspaceId = "c87da4cf-2406-463c-9a64-bb458fc9e05f" ,@Name = "LH_SILVER_LAYER""
#  - execute "
#         DECLARE @LandingzoneEntityIdInternal INT = (SELECT LandingzoneEntityId FROM integration.LandingzoneEntity WHERE SourceSchema = 'in' and SourceName = 'customer')
#         DECLARE @DataSourceIdInternal INT = (SELECT DataSourceId FROM integration.DataSource WHERE Name = 'LH_DATA_LANDINGZONE' and Type='ONELAKE_TABLES_01')
#         DECLARE @LakehouseIdInternal INT = (SELECT top 1 LakehouseId FROM integration.Lakehouse WHERE Name = 'LH_DATA_LANDINGZONE')
#         EXECUTE [integration].[sp_UpsertLandingzoneEntity]
#             @LandingzoneEntityId = @LandingzoneEntityIdInternal
#             ,@DataSourceId = @DataSourceIdInternal
#             ,@LakehouseId = @LakehouseIdInternal
#             ,@SourceSchema = 'in'
#             ,@SourceName = 'customer'
#             ,@SourceCustomSelect = ''
#             ,@FileName = 'customer'
#             ,@FilePath = 'fmd'
#             ,@FileType = 'parquet'
#             ,@IsIncremental = 0
#             ,@IsIncrementalColumn = ''
#             ,@IsActive = 1
#             ,@CustomNotebookName = ''
#     "
#  - execute "
#         DECLARE @LandingzoneEntityIdInternal INT = (SELECT LandingzoneEntityId FROM integration.LandingzoneEntity WHERE SourceSchema = 'in' and SourceName = 'customer')
#         DECLARE @BronzeLayerEntityIdInternal INT = (SELECT BronzeLayerEntityId FROM integration.BronzeLayerEntity WHERE [Schema] = 'in' and [Name] = 'customer')
#         DECLARE @LakehouseIdInternal INT = (SELECT top 1 LakehouseId FROM integration.Lakehouse WHERE Name = 'LH_BRONZE_LAYER')
#         EXECUTE [integration].[sp_UpsertBronzeLayerEntity]
#             @BronzeLayerEntityId = @BronzeLayerEntityIdInternal
#             ,@LandingzoneEntityId = @LandingzoneEntityIdInternal
#             ,@Schema = 'in'
#             ,@Name = 'customer'
#             ,@FileType = 'Delta'
#             ,@LakehouseId = @LakehouseIdInternal
#             ,@PrimaryKeys = 'CustomerId'
#             ,@IsActive = 1
#     "
#  - execute "
#         DECLARE @BronzeLayerEntityIdInternal INT = (SELECT BronzeLayerEntityId FROM integration.BronzeLayerEntity WHERE [Schema] = 'in' and [Name] = 'customer')
#         DECLARE @SilverLayerEntityIdInternal INT = (SELECT SilverLayerEntityId FROM integration.SilverLayerEntity WHERE [Schema] = 'in' and [Name] = 'customer')
#         DECLARE @LakehouseIdInternal INT = (SELECT top 1 LakehouseId FROM integration.Lakehouse WHERE Name = 'LH_SILVER_LAYER')
#         EXECUTE [integration].[sp_UpsertSilverLayerEntity]
#             @SilverLayerEntityId = @SilverLayerEntityIdInternal
#             ,@BronzeLayerEntityId = @BronzeLayerEntityIdInternal
#             ,@LakehouseId = @LakehouseIdInternal
#             ,@Name = 'customer'
#             ,@Schema = 'in'
#             ,@FileType = 'delta'
#             ,@IsActive = 1
#     "

# %%
display(tasks)
